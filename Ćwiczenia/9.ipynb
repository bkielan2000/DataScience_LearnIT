# %% [markdown]
# ---
# ## 🧪 Zadania do samodzielnej pracy
#
# Poniżej **20 zadań** w trzech poziomach trudności. Dla każdego zadania podana jest treść, a pod nią **przykładowe pełne rozwiązanie**.
#
#
#
# ### ✏️ Zadania podstawowe (1–8)

# %% [markdown]
# **Zadanie 1 – Tworzenie klasy Produkt** *(proste)*
#
# Stwórz klasę `Produkt` z atrybutami: `nazwa`, `cena`, `ilosc_w_magazynie`. Dodaj metody:
# - `pokaz_info()` – wyświetla informacje o produkcie
# - `sprzedaj(ilosc)` – zmniejsza `ilosc_w_magazynie` o podaną wartość
# - `dostawa(ilosc)` – zwiększa `ilosc_w_magazynie`
#
# Stwórz 3 obiekty i przetestuj metody.

# %%
# Twoje rozwiązanie

# %% [markdown]
# **Zadanie 2 – Klasa Kalkulator** *(proste)*
#
# Stwórz klasę `Kalkulator` z metodami: `dodaj(a, b)`, `odejmij(a, b)`, `pomnoz(a, b)`, `podziel(a, b)`. Stwórz obiekt i wykonaj przykładowe obliczenia.

# %%
# Twoje rozwiązanie

# %% [markdown]
# **Zadanie 3 – Klasa BankAccount** *(proste)*
#
# Stwórz klasę `BankAccount` z atrybutami: `wlasciciel`, `saldo`. Metody:
# - `wplac(kwota)` – zwiększa saldo
# - `wyplac(kwota)` – zmniejsza saldo (tylko jeśli wystarczy środków)
# - `pokaz_saldo()` – wyświetla saldo
#
# Stwórz kilka kont i przetestuj operacje.

# %%
# Twoje rozwiązanie

# %% [markdown]
# **Zadanie 4 – Klasa Ksiazka** *(proste)*
#
# Stwórz klasę `Ksiazka` z atrybutami: `tytul`, `autor`, `rok_wydania`, `liczba_stron`. Dodaj metodę `__str__()` zwracającą czytelną reprezentację. Stwórz listę 5 książek i wyświetl je używając `print()`.

# %%
# Twoje rozwiązanie

# %% [markdown]
# **Zadanie 5 – Klasa Student** *(proste)*
#
# Stwórz klasę `Student` z atrybutami: `imie`, `numer_indeksu`, `oceny` (lista). Metody: `dodaj_ocene(ocena)`, `srednia()`, `__str__()`. Stwórz 3 studentów, dodaj oceny i wyświetl średnie.

# %%
# Twoje rozwiązanie

# %% [markdown]
# **Zadanie 6 – Dziedziczenie: Pojazd i Samochod** *(proste)*
#
# Stwórz klasę bazową `Pojazd` (`marka`, `model`, `rok`). Stwórz klasę potomną `Samochod` z dodatkowym atrybutem `liczba_drzwi`. Dodaj `pokaz_info()` w obu klasach. Stwórz obiekt `Samochod` i wywołaj metodę.

# %%
# Twoje rozwiązanie

# %% [markdown]
# **Zadanie 7 – Klasa Pracownik** *(proste)*
#
# Stwórz klasę `Pracownik` (`imie`, `stanowisko`, `pensja`). Metody: `podwyzka(procent)`, `__str__()`. Stwórz 3 pracowników i daj im podwyżki.

# %%
# Twoje rozwiązanie

# %% [markdown]
# **Zadanie 8 – Klasa Zadanie (TODO list)** *(proste)*
#
# Stwórz klasę `Zadanie` (`opis`, `status` domyślnie "do zrobienia"). Metody: `oznacz_jako_zrobione()`, `__str__()`. Stwórz listę 5 zadań i oznacz część jako zrobione.

# %%
# Twoje rozwiązanie

# %% [markdown]
# ### ✏️ Zadania średnie (9–12)

# %% [markdown]
# **Zadanie 9 – Pipeline z wieloma krokami** *(średnie)*
#
# Stwórz 4 komponenty: `FiltrowanieDodatnich` (usuwa ujemne), `Zaokraglanie` (do całkowitych), `Skalowanie` (mnoży przez współczynnik), `Sumowanie` (suma listy). Stwórz klasę `Pipeline` i przetestuj na `[1.7, -3.2, 5.8, -1.1, 8.3, 2.4]`.

# %%
# Twoje rozwiązanie

# %% [markdown]
# **Zadanie 10 – Klasa Zamowienie z kompozycją** *(średnie)*
#
# Stwórz klasę `Produkt` (`nazwa`, `cena`) oraz `Zamowienie` zawierającą listę produktów. Metody `Zamowienie`: `dodaj_produkt(produkt, ilosc)`, `laczna_wartosc()`, `pokaz_zamowienie()`. Stwórz zamówienie z 5 produktami.

# %%
# Twoje rozwiązanie

# %% [markdown]
# **Zadanie 11 – System ocen uczniów** *(średnie)*
#
# Stwórz klasy: `Uczen` (`imie`, `oceny`), `Klasa` (`nazwa`, `uczniowie`). Metody `Klasa`: `dodaj_ucznia(uczen)`, `srednia_klasy()`, `najlepszy_uczen()`. Stwórz klasę z 5 uczniami i oblicz statystyki.

# %%
# Twoje rozwiązanie

# %% [markdown]
# **Zadanie 12 – Dziedziczenie: FiguraGeometryczna** *(średnie)*
#
# Stwórz klasę bazową `Figura` z metodą `pole()`. Klasy potomne: `Prostokat(szerokosc, wysokosc)`, `Kolo(promien)`. Każda implementuje `pole()`. Stwórz listę figur i oblicz łączne pole.

# %%
# Twoje rozwiązanie

# %% [markdown]
# ### 🧠 Zadania wyzwanie (13–20)

# %% [markdown]
# **Zadanie 13 – System biblioteki** *(challenge)*
#
# Klasy: `Ksiazka` (`tytul`, `autor`, `dostepna=True`), `Uzytkownik` (`imie`, `wypozyczone_ksiazki`), `Biblioteka` (`ksiazki`, `uzytkownicy`). Metody `Biblioteka`: `dodaj_ksiazke`, `zarejestruj_uzytkownika`, `wypozycz`, `zwroc`, `raport`. Zasymuluj wypożyczenia i zwroty.

# %%
# Twoje rozwiązanie

# %% [markdown]
# **Zadanie 14 – Pipeline ML z różnymi transformerami** *(challenge)*
#
# Zaimplementuj: `LogTransformer` (log(x+1)), `OutlierRemover` (usuwa wartości > 3·std od średniej), `BinningTransformer` (dzieli na przedziały). Stwórz pipeline i przetestuj na `[1, 5, 10, 100, 2, 3, 8, 200, 4, 6]`.

# %%
# Twoje rozwiązanie

# %% [markdown]
# **Zadanie 15 – Symulator portfela inwestycyjnego** *(challenge)*
#
# Klasy: `Akcja` (`nazwa`, `cena_kupna`, `cena_aktualna`), `Portfel` (`akcje`, `kapital_poczatkowy`). Metody `Portfel`: `kup_akcje`, `sprzedaj_akcje`, `aktualizuj_ceny`, `wartosc_portfela`, `zysk_strata`. Zasymuluj kupno/sprzedaż 5 akcji.

# %%
# Twoje rozwiązanie

# %% [markdown]
# **Zadanie 16 – Dziedziczenie wielopoziomowe: Zwierzęta** *(challenge)*
#
# Struktura: `Zwierze` (`nazwa`, `wiek`) → `Ssak(Zwierze)` (`typ_futra`) → `Pies(Ssak)` (`rasa`). Każda klasa ma `pokaz_info()` wyświetlającą wszystkie atrybuty. Stwórz obiekt `Pies` i wywołaj metodę.

# %%
# Twoje rozwiązanie

# %% [markdown]
# **Zadanie 17 – System rezerwacji hotelu** *(challenge)*
#
# Klasy: `Pokoj` (`numer`, `typ`, `cena_za_noc`, `zajety=False`), `Rezerwacja` (`pokoj`, `data_od`, `data_do`, `gosc`), `Hotel` (`pokoje`, `rezerwacje`). Metody `Hotel`: `dodaj_pokoj`, `rezerwuj`, `wolne_pokoje`, `przychod`. Zasymuluj 10 pokoi i 5 rezerwacji.
#
# > *Uproszczenie:* daty reprezentujemy jako liczby dni (np. `data_od=1`, `data_do=4` ⇒ 3 noce), żeby nie wchodzić jeszcze w moduł `datetime`.

# %%
# Twoje rozwiązanie

# %% [markdown]
# **Zadanie 18 – Pipeline z walidacją danych** *(challenge)*
#
# Komponenty: `ValidatorZakresu(min, max)`, `ValidatorTypu(typ)`, `ValidatorBrakow`. Każdy validator zwraca `(True/False, komunikat)`. Pipeline agreguje wyniki walidacji.

# %%
# Twoje rozwiązanie

# %% [markdown]
# **Zadanie 19 – Gra RPG z klasami postaci** *(challenge)*
#
# Klasy: `Postac` (`imie`, `hp`, `atak`, `obrona`), `Wojownik` (zwiększony atak), `Mag` (czary), `Lucznik` (zwiększona szybkość). Metody: `atakuj(cel)`, `leczenie(punkty)`. Zasymuluj walkę 3 postaci.

# %%
# Twoje rozwiązanie

# %% [markdown]
# **Zadanie 20 – Ekosystem transformerów danych** *(challenge)*
#
# Hierarchia: `BaseTransformer` (z metodą `transform(dane)`), `DropNullTransformer`, `ClipTransformer(min, max)`, `SquareTransformer`, `InverseTransformer` (1/x). Stwórz `Pipeline` z 4 transformerami i dodaj metodę `fit_transform(dane)` analogiczną do scikit-learn.

# %%
# Twoje rozwiązanie
